# %% [markdown]
# # Segmentation by registration and feature extraction

# %%
import glob
import os
import os.path
import numpy as np
import pandas as pd
import maweight
import pickle
import logging
import tqdm
from tqdm.contrib import tzip

from config import manually_segmented_path, dissected_path, path_prefix_data
from config import output_path, skull_features_path, head_features_path 
from config import save_registered_images
from config import bin_width, bin_min, bin_max, threshold
from config import tmp_path, elastix_params, threads

manually_segmented_bone_path = os.path.join(path_prefix_data, "manually_labels_bone")
dissected_bone_path = os.path.join(path_prefix_data, "dissected_bone")        

bone_registration_path = os.path.join(path_prefix_data, "bone_regsitration")
os.makedirs(bone_registration_path, exist_ok=True)

registration_after_bone_registration = True

image_format = "." + elastix_params['ResultImageFormat']

import warnings
warnings.filterwarnings('ignore')

LIMIT=None

# setting the logging format
FORMAT = '%(asctime)-15s %(clientip)s %(user)-8s %(message)s'
logging.basicConfig(format=FORMAT, level=logging.INFO)

# %%
#delete all '_' character from filenames
def rename_files(files):
    new_files = [os.path.join(os.path.dirname(file), os.path.basename(file).replace("_", "")) for file in files]
    [os.rename(rfiles[0], rfiles[1]) for rfiles in zip(files, new_files)]
    return new_files

# %% [markdown]
# ## Discovering files to process

# %%
manually_segmented_files = []
manually_segmented_files += sorted(glob.glob(os.path.join(manually_segmented_path, '*.nii')))
manually_segmented_files += sorted(glob.glob(os.path.join(manually_segmented_path, '*.nii.gz')))

manually_segmented_files = rename_files(manually_segmented_files)

manually_segmented_images= [f for f in manually_segmented_files if not 'head' in 
                            f.split(os.sep)[-1] and not 'skull' in f.split(os.sep)[-1]]
manually_segmented_head= [f for f in manually_segmented_files if 'head' in f]
manually_segmented_skulls= [f for f in manually_segmented_files if 'skull' in f]

dissected_images = []
dissected_images = glob.glob(os.path.join(dissected_path, '*.nii'))
dissected_images += glob.glob(os.path.join(dissected_path, '*.nii.gz'))
dissected_images = sorted(dissected_images)

manually_segmented_bones = []
if os.path.exists(manually_segmented_bone_path):
    manually_segmented_bones = glob.glob(os.path.join(manually_segmented_bone_path, '*.nii'))
    manually_segmented_bones += glob.glob(os.path.join(manually_segmented_bone_path, '*.nii.gz'))
    manually_segmented_bones = sorted(manually_segmented_bones)

dissected_bones = []
if os.path.exists(dissected_bone_path):
    dissected_bones = glob.glob(os.path.join(dissected_bone_path, '*.nii'))
    dissected_bones += glob.glob(os.path.join(dissected_bone_path, '*.nii.gz'))
    dissected_bones = sorted(dissected_bones)    


if LIMIT:
    dissected_images= dissected_images[:LIMIT]

dissected_images = rename_files(dissected_images)
print(f"Number of dissected images: {len(dissected_images)}")
print(f"Number of dissected bone masks: {len(dissected_bones)}")
print(f"Number of manually segmented images: {len(manually_segmented_images)}")
print(f"Number of skull masks: {len(manually_segmented_skulls)}")
print(f"Number of head masks: {len(manually_segmented_head)}")
print(f"Number of bone masks: {len(manually_segmented_bones)}")
# Out:
# Number of dissected images: 170
# Number of dissected bone masks: 170
# Number of manually segmented images: 20
# Number of skull masks: 20
# Number of head masks: 20
# Number of bone masks: 20

# %% [markdown]
# ## Set Origin to Center of Mass

# %%
for d, b in zip(dissected_images, dissected_bones): 
    maweight.origin_to_center_of_mass(d, [b])
for i, h, m, b in zip(manually_segmented_images, manually_segmented_skulls, manually_segmented_head, manually_segmented_bones):
    maweight.origin_to_center_of_mass(i, [h, m, b])
# Out:
# Processing image: data/dissected/197a.nii.gz and masks: []
# Center of Mass of data/dissected/197a.nii.gz is already in origin.
# Processing image: data/dissected/197f.nii.gz and masks: []
# Center of Mass of data/dissected/197f.nii.gz is already in origin.
# Processing image: data/dissected/197k.nii.gz and masks: []
# Center of Mass of data/dissected/197k.nii.gz is already in origin.
# Processing image: data/dissected/198a.nii.gz and masks: []
# Center of Mass of data/dissected/198a.nii.gz is already in origin.
# Processing image: data/dissected/198f.nii.gz and masks: []
# Center of Mass of data/dissected/198f.nii.gz is already in origin.
# Processing image: data/dissected/198k.nii.gz and masks: []
# Center of Mass of data/dissected/198k.nii.gz is already in origin.
# Processing image: data/dissected/199a.nii.gz and masks: []
# Center of Mass of data/dissected/199a.nii.gz is already in origin.
# Processing image: data/dissected/199k.nii.gz and masks: []
# Center of Mass of data/dissected/199k.nii.gz is already in origin.
# Processing image: data/dissected/200a.nii.gz and masks: []
# Center of Mass of data/dissected/200a.nii.gz is already in origin.
# Processing image: data/dissected/200f.nii.gz and masks: []
# Center of Mass of data/dissected/200f.nii.gz is already in origin.
# Processing image: data/dissected/200k.nii.gz and masks: []
# Center of Mass of data/dissected/200k.nii.gz is already in origin.
# Processing image: data/dissected/201a.nii.gz and masks: []
# Center of Mass of data/dissected/201a.nii.gz is already in origin.
# Processing image: data/dissected/201f.nii.gz and masks: []
# Center of Mass of data/dissected/201f.nii.gz is already in origin.
# Processing image: data/dissected/201k.nii.gz and masks: []
# Center of Mass of data/dissected/201k.nii.gz is already in origin.
# Processing image: data/dissected/202a.nii.gz and masks: []
# Center of Mass of data/dissected/202a.nii.gz is already in origin.
# Processing image: data/dissected/202f.nii.gz and masks: []
# Center of Mass of data/dissected/202f.nii.gz is already in origin.
# Processing image: data/dissected/202k.nii.gz and masks: []
# Center of Mass of data/dissected/202k.nii.gz is already in origin.
# Processing image: data/dissected/203a.nii.gz and masks: []
# Center of Mass of data/dissected/203a.nii.gz is already in origin.
# Processing image: data/dissected/203f.nii.gz and masks: []
# Center of Mass of data/dissected/203f.nii.gz is already in origin.
# Processing image: data/dissected/203k.nii.gz and masks: []
# Center of Mass of data/dissected/203k.nii.gz is already in origin.
# Processing image: data/dissected/204a.nii.gz and masks: []
# Center of Mass of data/dissected/204a.nii.gz is already in origin.
# Processing image: data/dissected/204f.nii.gz and masks: []
# Center of Mass of data/dissected/204f.nii.gz is already in origin.
# Processing image: data/dissected/204k.nii.gz and masks: []
# Center of Mass of data/dissected/204k.nii.gz is already in origin.
# Processing image: data/dissected/205a.nii.gz and masks: []
# Center of Mass of data/dissected/205a.nii.gz is already in origin.
# Processing image: data/dissected/205f.nii.gz and masks: []
# Center of Mass of data/dissected/205f.nii.gz is already in origin.
# Processing image: data/dissected/205k.nii.gz and masks: []
# Center of Mass of data/dissected/205k.nii.gz is already in origin.
# Processing image: data/dissected/206a.nii.gz and masks: []
# Center of Mass of data/dissected/206a.nii.gz is already in origin.
# Processing image: data/dissected/206f.nii.gz and masks: []
# Center of Mass of data/dissected/206f.nii.gz is already in origin.
# Processing image: data/dissected/206k.nii.gz and masks: []
# Center of Mass of data/dissected/206k.nii.gz is already in origin.
# Processing image: data/dissected/207a.nii.gz and masks: []
# Center of Mass of data/dissected/207a.nii.gz is already in origin.
# Processing image: data/dissected/207f.nii.gz and masks: []
# Center of Mass of data/dissected/207f.nii.gz is already in origin.
# Processing image: data/dissected/207k.nii.gz and masks: []
# Center of Mass of data/dissected/207k.nii.gz is already in origin.
# Processing image: data/dissected/208a.nii.gz and masks: []
# Center of Mass of data/dissected/208a.nii.gz is already in origin.
# Processing image: data/dissected/208f.nii.gz and masks: []
# Center of Mass of data/dissected/208f.nii.gz is already in origin.
# Processing image: data/dissected/208k.nii.gz and masks: []
# Center of Mass of data/dissected/208k.nii.gz is already in origin.
# Processing image: data/dissected/209a.nii.gz and masks: []
# Center of Mass of data/dissected/209a.nii.gz is already in origin.
# Processing image: data/dissected/209f.nii.gz and masks: []
# Center of Mass of data/dissected/209f.nii.gz is already in origin.
# Processing image: data/dissected/209k.nii.gz and masks: []
# Center of Mass of data/dissected/209k.nii.gz is already in origin.
# Processing image: data/dissected/210a.nii.gz and masks: []
# Center of Mass of data/dissected/210a.nii.gz is already in origin.
# Processing image: data/dissected/210f.nii.gz and masks: []
# Center of Mass of data/dissected/210f.nii.gz is already in origin.
# Processing image: data/dissected/210k.nii.gz and masks: []
# Center of Mass of data/dissected/210k.nii.gz is already in origin.
# Processing image: data/dissected/211a.nii.gz and masks: []
# Center of Mass of data/dissected/211a.nii.gz is already in origin.
# Processing image: data/dissected/211f.nii.gz and masks: []
# Center of Mass of data/dissected/211f.nii.gz is already in origin.
# Processing image: data/dissected/211k.nii.gz and masks: []
# Center of Mass of data/dissected/211k.nii.gz is already in origin.
# Processing image: data/dissected/212a.nii.gz and masks: []
# Center of Mass of data/dissected/212a.nii.gz is already in origin.
# Processing image: data/dissected/212f.nii.gz and masks: []
# Center of Mass of data/dissected/212f.nii.gz is already in origin.
# Processing image: data/dissected/212k.nii.gz and masks: []
# Center of Mass of data/dissected/212k.nii.gz is already in origin.
# Processing image: data/dissected/213a.nii.gz and masks: []
# Center of Mass of data/dissected/213a.nii.gz is already in origin.
# Processing image: data/dissected/213f.nii.gz and masks: []
# Center of Mass of data/dissected/213f.nii.gz is already in origin.
# Processing image: data/dissected/213k.nii.gz and masks: []
# Center of Mass of data/dissected/213k.nii.gz is already in origin.
# Processing image: data/dissected/214a.nii.gz and masks: []
# Center of Mass of data/dissected/214a.nii.gz is already in origin.
# Processing image: data/dissected/214f.nii.gz and masks: []
# Center of Mass of data/dissected/214f.nii.gz is already in origin.
# Processing image: data/dissected/214k.nii.gz and masks: []
# Center of Mass of data/dissected/214k.nii.gz is already in origin.
# Processing image: data/dissected/215a.nii.gz and masks: []
# Center of Mass of data/dissected/215a.nii.gz is already in origin.
# Processing image: data/dissected/215f.nii.gz and masks: []
# Center of Mass of data/dissected/215f.nii.gz is already in origin.
# Processing image: data/dissected/215k.nii.gz and masks: []
# Center of Mass of data/dissected/215k.nii.gz is already in origin.
# Processing image: data/dissected/216a.nii.gz and masks: []
# Center of Mass of data/dissected/216a.nii.gz is already in origin.
# Processing image: data/dissected/216f.nii.gz and masks: []
# Center of Mass of data/dissected/216f.nii.gz is already in origin.
# Processing image: data/dissected/216k.nii.gz and masks: []
# Center of Mass of data/dissected/216k.nii.gz is already in origin.
# Processing image: data/dissected/217a.nii.gz and masks: []
# Center of Mass of data/dissected/217a.nii.gz is already in origin.
# Processing image: data/dissected/217f.nii.gz and masks: []
# Center of Mass of data/dissected/217f.nii.gz is already in origin.
# Processing image: data/dissected/217k.nii.gz and masks: []
# Center of Mass of data/dissected/217k.nii.gz is already in origin.
# Processing image: data/dissected/218a.nii.gz and masks: []
# Center of Mass of data/dissected/218a.nii.gz is already in origin.
# Processing image: data/dissected/218f.nii.gz and masks: []
# Center of Mass of data/dissected/218f.nii.gz is already in origin.
# Processing image: data/dissected/218k.nii.gz and masks: []
# Center of Mass of data/dissected/218k.nii.gz is already in origin.
# Processing image: data/dissected/219a.nii.gz and masks: []
# Center of Mass of data/dissected/219a.nii.gz is already in origin.
# Processing image: data/dissected/219f.nii.gz and masks: []
# Center of Mass of data/dissected/219f.nii.gz is already in origin.
# Processing image: data/dissected/219k.nii.gz and masks: []
# Center of Mass of data/dissected/219k.nii.gz is already in origin.
# Processing image: data/dissected/220a.nii.gz and masks: []
# Center of Mass of data/dissected/220a.nii.gz is already in origin.
# Processing image: data/dissected/220f.nii.gz and masks: []
# Center of Mass of data/dissected/220f.nii.gz is already in origin.
# Processing image: data/dissected/220k.nii.gz and masks: []
# Center of Mass of data/dissected/220k.nii.gz is already in origin.
# Processing image: data/dissected/221a.nii.gz and masks: []
# Center of Mass of data/dissected/221a.nii.gz is already in origin.
# Processing image: data/dissected/221f.nii.gz and masks: []
# Center of Mass of data/dissected/221f.nii.gz is already in origin.
# Processing image: data/dissected/221k.nii.gz and masks: []
# Center of Mass of data/dissected/221k.nii.gz is already in origin.
# Processing image: data/dissected/222a.nii.gz and masks: []
# Center of Mass of data/dissected/222a.nii.gz is already in origin.
# Processing image: data/dissected/222f.nii.gz and masks: []
# Center of Mass of data/dissected/222f.nii.gz is already in origin.
# Processing image: data/dissected/222k.nii.gz and masks: []
# Center of Mass of data/dissected/222k.nii.gz is already in origin.
# Processing image: data/dissected/223a.nii.gz and masks: []
# Center of Mass of data/dissected/223a.nii.gz is already in origin.
# Processing image: data/dissected/223f.nii.gz and masks: []
# Center of Mass of data/dissected/223f.nii.gz is already in origin.
# Processing image: data/dissected/223k.nii.gz and masks: []
# Center of Mass of data/dissected/223k.nii.gz is already in origin.
# Processing image: data/dissected/224a.nii.gz and masks: []
# Center of Mass of data/dissected/224a.nii.gz is already in origin.
# Processing image: data/dissected/224f.nii.gz and masks: []
# Center of Mass of data/dissected/224f.nii.gz is already in origin.
# Processing image: data/dissected/224k.nii.gz and masks: []
# Center of Mass of data/dissected/224k.nii.gz is already in origin.
# Processing image: data/dissected/225a.nii.gz and masks: []
# Center of Mass of data/dissected/225a.nii.gz is already in origin.
# Processing image: data/dissected/225f.nii.gz and masks: []
# Center of Mass of data/dissected/225f.nii.gz is already in origin.
# Processing image: data/dissected/225k.nii.gz and masks: []
# Center of Mass of data/dissected/225k.nii.gz is already in origin.
# Processing image: data/dissected/226a.nii.gz and masks: []
# Center of Mass of data/dissected/226a.nii.gz is already in origin.
# Processing image: data/dissected/226f.nii.gz and masks: []
# Center of Mass of data/dissected/226f.nii.gz is already in origin.
# Processing image: data/dissected/226k.nii.gz and masks: []
# Center of Mass of data/dissected/226k.nii.gz is already in origin.
# Processing image: data/dissected/227a.nii.gz and masks: []
# Center of Mass of data/dissected/227a.nii.gz is already in origin.
# Processing image: data/dissected/227f.nii.gz and masks: []
# Center of Mass of data/dissected/227f.nii.gz is already in origin.
# Processing image: data/dissected/227k.nii.gz and masks: []
# Center of Mass of data/dissected/227k.nii.gz is already in origin.
# Processing image: data/dissected/228a.nii.gz and masks: []
# Center of Mass of data/dissected/228a.nii.gz is already in origin.
# Processing image: data/dissected/228f.nii.gz and masks: []
# Center of Mass of data/dissected/228f.nii.gz is already in origin.
# Processing image: data/dissected/228k.nii.gz and masks: []
# Center of Mass of data/dissected/228k.nii.gz is already in origin.
# Processing image: data/dissected/229a.nii.gz and masks: []
# Center of Mass of data/dissected/229a.nii.gz is already in origin.
# Processing image: data/dissected/229f.nii.gz and masks: []
# Center of Mass of data/dissected/229f.nii.gz is already in origin.
# Processing image: data/dissected/229k.nii.gz and masks: []
# Center of Mass of data/dissected/229k.nii.gz is already in origin.
# Processing image: data/dissected/230a.nii.gz and masks: []
# Center of Mass of data/dissected/230a.nii.gz is already in origin.
# Processing image: data/dissected/230f.nii.gz and masks: []
# Center of Mass of data/dissected/230f.nii.gz is already in origin.
# Processing image: data/dissected/230k.nii.gz and masks: []
# Center of Mass of data/dissected/230k.nii.gz is already in origin.
# Processing image: data/dissected/231a.nii.gz and masks: []
# Center of Mass of data/dissected/231a.nii.gz is already in origin.
# Processing image: data/dissected/231f.nii.gz and masks: []
# Center of Mass of data/dissected/231f.nii.gz is already in origin.
# Processing image: data/dissected/231k.nii.gz and masks: []
# Center of Mass of data/dissected/231k.nii.gz is already in origin.
# Processing image: data/dissected/232a.nii.gz and masks: []
# Center of Mass of data/dissected/232a.nii.gz is already in origin.
# Processing image: data/dissected/232f.nii.gz and masks: []
# Center of Mass of data/dissected/232f.nii.gz is already in origin.
# Processing image: data/dissected/232k.nii.gz and masks: []
# Center of Mass of data/dissected/232k.nii.gz is already in origin.
# Processing image: data/dissected/233a.nii.gz and masks: []
# Center of Mass of data/dissected/233a.nii.gz is already in origin.
# Processing image: data/dissected/233f.nii.gz and masks: []
# Center of Mass of data/dissected/233f.nii.gz is already in origin.
# Processing image: data/dissected/233k.nii.gz and masks: []
# Center of Mass of data/dissected/233k.nii.gz is already in origin.
# Processing image: data/dissected/234a.nii.gz and masks: []
# Center of Mass of data/dissected/234a.nii.gz is already in origin.
# Processing image: data/dissected/234f.nii.gz and masks: []
# Center of Mass of data/dissected/234f.nii.gz is already in origin.
# Processing image: data/dissected/234k.nii.gz and masks: []
# Center of Mass of data/dissected/234k.nii.gz is already in origin.
# Processing image: data/dissected/235a.nii.gz and masks: []
# Center of Mass of data/dissected/235a.nii.gz is already in origin.
# Processing image: data/dissected/235f.nii.gz and masks: []
# Center of Mass of data/dissected/235f.nii.gz is already in origin.
# Processing image: data/dissected/235k.nii.gz and masks: []
# Center of Mass of data/dissected/235k.nii.gz is already in origin.
# Processing image: data/dissected/236a.nii.gz and masks: []
# Center of Mass of data/dissected/236a.nii.gz is already in origin.
# Processing image: data/dissected/236f.nii.gz and masks: []
# Center of Mass of data/dissected/236f.nii.gz is already in origin.
# Processing image: data/dissected/236k.nii.gz and masks: []
# Center of Mass of data/dissected/236k.nii.gz is already in origin.
# Processing image: data/dissected/237a.nii.gz and masks: []
# Center of Mass of data/dissected/237a.nii.gz is already in origin.
# Processing image: data/dissected/237f.nii.gz and masks: []
# Center of Mass of data/dissected/237f.nii.gz is already in origin.
# Processing image: data/dissected/237k.nii.gz and masks: []
# Center of Mass of data/dissected/237k.nii.gz is already in origin.
# Processing image: data/dissected/238a.nii.gz and masks: []
# Center of Mass of data/dissected/238a.nii.gz is already in origin.
# Processing image: data/dissected/238f.nii.gz and masks: []
# Center of Mass of data/dissected/238f.nii.gz is already in origin.
# Processing image: data/dissected/238k.nii.gz and masks: []
# Center of Mass of data/dissected/238k.nii.gz is already in origin.
# Processing image: data/dissected/239a.nii.gz and masks: []
# Center of Mass of data/dissected/239a.nii.gz is already in origin.
# Processing image: data/dissected/239f.nii.gz and masks: []
# Center of Mass of data/dissected/239f.nii.gz is already in origin.
# Processing image: data/dissected/239k.nii.gz and masks: []
# Center of Mass of data/dissected/239k.nii.gz is already in origin.
# Processing image: data/dissected/240a.nii.gz and masks: []
# Center of Mass of data/dissected/240a.nii.gz is already in origin.
# Processing image: data/dissected/240f.nii.gz and masks: []
# Center of Mass of data/dissected/240f.nii.gz is already in origin.
# Processing image: data/dissected/240k.nii.gz and masks: []
# Center of Mass of data/dissected/240k.nii.gz is already in origin.
# Processing image: data/dissected/241a.nii.gz and masks: []
# Center of Mass of data/dissected/241a.nii.gz is already in origin.
# Processing image: data/dissected/241f.nii.gz and masks: []
# Center of Mass of data/dissected/241f.nii.gz is already in origin.
# Processing image: data/dissected/241k.nii.gz and masks: []
# Center of Mass of data/dissected/241k.nii.gz is already in origin.
# Processing image: data/dissected/242a.nii.gz and masks: []
# Center of Mass of data/dissected/242a.nii.gz is already in origin.
# Processing image: data/dissected/242f.nii.gz and masks: []
# Center of Mass of data/dissected/242f.nii.gz is already in origin.
# Processing image: data/dissected/242k.nii.gz and masks: []
# Center of Mass of data/dissected/242k.nii.gz is already in origin.
# Processing image: data/dissected/243a.nii.gz and masks: []
# Center of Mass of data/dissected/243a.nii.gz is already in origin.
# Processing image: data/dissected/243f.nii.gz and masks: []
# Center of Mass of data/dissected/243f.nii.gz is already in origin.
# Processing image: data/dissected/243k.nii.gz and masks: []
# Center of Mass of data/dissected/243k.nii.gz is already in origin.
# Processing image: data/dissected/244a.nii.gz and masks: []
# Center of Mass of data/dissected/244a.nii.gz is already in origin.
# Processing image: data/dissected/244f.nii.gz and masks: []
# Center of Mass of data/dissected/244f.nii.gz is already in origin.
# Processing image: data/dissected/244k.nii.gz and masks: []
# Center of Mass of data/dissected/244k.nii.gz is already in origin.
# Processing image: data/dissected/245a.nii.gz and masks: []
# Center of Mass of data/dissected/245a.nii.gz is already in origin.
# Processing image: data/dissected/245f.nii.gz and masks: []
# Center of Mass of data/dissected/245f.nii.gz is already in origin.
# Processing image: data/dissected/245k.nii.gz and masks: []
# Center of Mass of data/dissected/245k.nii.gz is already in origin.
# Processing image: data/dissected/246a.nii.gz and masks: []
# Center of Mass of data/dissected/246a.nii.gz is already in origin.
# Processing image: data/dissected/246f.nii.gz and masks: []
# Center of Mass of data/dissected/246f.nii.gz is already in origin.
# Processing image: data/dissected/246k.nii.gz and masks: []
# Center of Mass of data/dissected/246k.nii.gz is already in origin.
# Processing image: data/dissected/247a.nii.gz and masks: []
# Center of Mass of data/dissected/247a.nii.gz is already in origin.
# Processing image: data/dissected/247f.nii.gz and masks: []
# Center of Mass of data/dissected/247f.nii.gz is already in origin.
# Processing image: data/dissected/247k.nii.gz and masks: []
# Center of Mass of data/dissected/247k.nii.gz is already in origin.
# Processing image: data/dissected/248a.nii.gz and masks: []
# Center of Mass of data/dissected/248a.nii.gz is already in origin.
# Processing image: data/dissected/248f.nii.gz and masks: []
# Center of Mass of data/dissected/248f.nii.gz is already in origin.
# Processing image: data/dissected/248k.nii.gz and masks: []
# Center of Mass of data/dissected/248k.nii.gz is already in origin.
# Processing image: data/dissected/249a.nii.gz and masks: []
# Center of Mass of data/dissected/249a.nii.gz is already in origin.
# Processing image: data/dissected/249f.nii.gz and masks: []
# Center of Mass of data/dissected/249f.nii.gz is already in origin.
# Processing image: data/dissected/249k.nii.gz and masks: []
# Center of Mass of data/dissected/249k.nii.gz is already in origin.
# Processing image: data/dissected/250a.nii.gz and masks: []
# Center of Mass of data/dissected/250a.nii.gz is already in origin.
# Processing image: data/dissected/250f.nii.gz and masks: []
# Center of Mass of data/dissected/250f.nii.gz is already in origin.
# Processing image: data/dissected/250k.nii.gz and masks: []
# Center of Mass of data/dissected/250k.nii.gz is already in origin.
# Processing image: data/dissected/251a.nii.gz and masks: []
# Center of Mass of data/dissected/251a.nii.gz is already in origin.
# Processing image: data/dissected/251f.nii.gz and masks: []
# Center of Mass of data/dissected/251f.nii.gz is already in origin.
# Processing image: data/dissected/251k.nii.gz and masks: []
# Center of Mass of data/dissected/251k.nii.gz is already in origin.
# Processing image: data/dissected/252a.nii.gz and masks: []
# Center of Mass of data/dissected/252a.nii.gz is already in origin.
# Processing image: data/dissected/252f.nii.gz and masks: []
# Center of Mass of data/dissected/252f.nii.gz is already in origin.
# Processing image: data/dissected/252k.nii.gz and masks: []
# Center of Mass of data/dissected/252k.nii.gz is already in origin.
# Processing image: data/dissected/253a.nii.gz and masks: []
# Center of Mass of data/dissected/253a.nii.gz is already in origin.
# Processing image: data/dissected/253f.nii.gz and masks: []
# Center of Mass of data/dissected/253f.nii.gz is already in origin.
# Processing image: data/dissected/253k.nii.gz and masks: []
# Center of Mass of data/dissected/253k.nii.gz is already in origin.
# Processing image: data/dissected/254a.nii.gz and masks: []
# Center of Mass of data/dissected/254a.nii.gz is already in origin.
# Processing image: data/dissected/254f.nii.gz and masks: []
# Center of Mass of data/dissected/254f.nii.gz is already in origin.
# Processing image: data/dissected/254k.nii.gz and masks: []
# Center of Mass of data/dissected/254k.nii.gz is already in origin.
# Processing image: data/dissected/255a.nii.gz and masks: []
# Center of Mass of data/dissected/255a.nii.gz is already in origin.
# Processing image: data/dissected/255f.nii.gz and masks: []
# Center of Mass of data/dissected/255f.nii.gz is already in origin.
# Processing image: data/dissected/255k.nii.gz and masks: []
# Center of Mass of data/dissected/255k.nii.gz is already in origin.
# Processing image: data/dissected/256a.nii.gz and masks: []
# Center of Mass of data/dissected/256a.nii.gz is already in origin.
# Processing image: data/dissected/256f.nii.gz and masks: []
# Center of Mass of data/dissected/256f.nii.gz is already in origin.
# Processing image: data/dissected/256k.nii.gz and masks: []
# Center of Mass of data/dissected/256k.nii.gz is already in origin.
# Processing image: data/manually_labels/127a.nii.gz and masks: ['data/manually_labels/127a-skull.nii.gz', 'data/manually_labels/127a-head.nii.gz']
# Center of Mass of data/manually_labels/127a.nii.gz is already in origin.
# Processing image: data/manually_labels/130a.nii.gz and masks: ['data/manually_labels/130a-skull.nii.gz', 'data/manually_labels/130a-head.nii.gz']
# Center of Mass of data/manually_labels/130a.nii.gz is already in origin.
# Processing image: data/manually_labels/139k.nii.gz and masks: ['data/manually_labels/139k-skull.nii.gz', 'data/manually_labels/139k-head.nii.gz']
# Center of Mass of data/manually_labels/139k.nii.gz is already in origin.
# Processing image: data/manually_labels/152k.nii.gz and masks: ['data/manually_labels/152k-skull.nii.gz', 'data/manually_labels/152k-head.nii.gz']
# Center of Mass of data/manually_labels/152k.nii.gz is already in origin.
# Processing image: data/manually_labels/166a.nii.gz and masks: ['data/manually_labels/166a-skull.nii.gz', 'data/manually_labels/166a-head.nii.gz']
# Center of Mass of data/manually_labels/166a.nii.gz is already in origin.
# Processing image: data/manually_labels/234a.nii.gz and masks: ['data/manually_labels/234a-skull.nii.gz', 'data/manually_labels/234a-head.nii.gz']
# Center of Mass of data/manually_labels/234a.nii.gz is already in origin.
# Processing image: data/manually_labels/237f.nii.gz and masks: ['data/manually_labels/237f-skull.nii.gz', 'data/manually_labels/237f-head.nii.gz']
# Center of Mass of data/manually_labels/237f.nii.gz is already in origin.
# Processing image: data/manually_labels/240k.nii.gz and masks: ['data/manually_labels/240k-skull.nii.gz', 'data/manually_labels/240k-head.nii.gz']
# Center of Mass of data/manually_labels/240k.nii.gz is already in origin.
# Processing image: data/manually_labels/246f.nii.gz and masks: ['data/manually_labels/246f-skull.nii.gz', 'data/manually_labels/246f-head.nii.gz']
# Center of Mass of data/manually_labels/246f.nii.gz is already in origin.
# Processing image: data/manually_labels/261a.nii.gz and masks: ['data/manually_labels/261a-skull.nii.gz', 'data/manually_labels/261a-head.nii.gz']
# Center of Mass of data/manually_labels/261a.nii.gz is already in origin.
# Processing image: data/manually_labels/274f.nii.gz and masks: ['data/manually_labels/274f-skull.nii.gz', 'data/manually_labels/274f-head.nii.gz']
# Center of Mass of data/manually_labels/274f.nii.gz is already in origin.
# Processing image: data/manually_labels/275k.nii.gz and masks: ['data/manually_labels/275k-skull.nii.gz', 'data/manually_labels/275k-head.nii.gz']
# Center of Mass of data/manually_labels/275k.nii.gz is already in origin.
# Processing image: data/manually_labels/284f.nii.gz and masks: ['data/manually_labels/284f-skull.nii.gz', 'data/manually_labels/284f-head.nii.gz']
# Center of Mass of data/manually_labels/284f.nii.gz is already in origin.
# Processing image: data/manually_labels/297a.nii.gz and masks: ['data/manually_labels/297a-skull.nii.gz', 'data/manually_labels/297a-head.nii.gz']
# Center of Mass of data/manually_labels/297a.nii.gz is already in origin.
# Processing image: data/manually_labels/298a.nii.gz and masks: ['data/manually_labels/298a-skull.nii.gz', 'data/manually_labels/298a-head.nii.gz']
# Center of Mass of data/manually_labels/298a.nii.gz is already in origin.
# Processing image: data/manually_labels/305a.nii.gz and masks: ['data/manually_labels/305a-skull.nii.gz', 'data/manually_labels/305a-head.nii.gz']
# Center of Mass of data/manually_labels/305a.nii.gz is already in origin.
# Processing image: data/manually_labels/310a.nii.gz and masks: ['data/manually_labels/310a-skull.nii.gz', 'data/manually_labels/310a-head.nii.gz']
# Center of Mass of data/manually_labels/310a.nii.gz is already in origin.
# Processing image: data/manually_labels/316k.nii.gz and masks: ['data/manually_labels/316k-skull.nii.gz', 'data/manually_labels/316k-head.nii.gz']
# Center of Mass of data/manually_labels/316k.nii.gz is already in origin.
# Processing image: data/manually_labels/319k.nii.gz and masks: ['data/manually_labels/319k-skull.nii.gz', 'data/manually_labels/319k-head.nii.gz']
# Center of Mass of data/manually_labels/319k.nii.gz is already in origin.
# Processing image: data/manually_labels/333k.nii.gz and masks: ['data/manually_labels/333k-skull.nii.gz', 'data/manually_labels/333k-head.nii.gz']
# Center of Mass of data/manually_labels/333k.nii.gz is already in origin.

# %% [markdown]
# ## Segmentation by Registration with bone

# %%
for d, db in tzip(dissected_images, dissected_bones):
    for (i, h, m, b) in zip(manually_segmented_images, manually_segmented_head, manually_segmented_skulls, manually_segmented_bones):
        output_skull= os.path.join(bone_registration_path, d.split(os.sep)[-1] + '_' + m.split(os.sep)[-1] + '_' + image_format)
        output_head= os.path.join(bone_registration_path, d.split(os.sep)[-1] + '_' + h.split(os.sep)[-1] + '_' + image_format)
        if save_registered_images:
            output_registered= os.path.join(bone_registration_path, d.split(os.sep)[-1] + '_' + i.split(os.sep)[-1] + '_' + image_format)
        else:
            output_registered= None
        if (not os.path.isfile(output_skull) or not os.path.isfile(output_head) or 
            (save_registered_images and not os.path.isfile(output_registered))):
            maweight.register_and_transform(i, d, [m, h], [output_skull, output_head], moving_mask= b, fixed_mask= db,
                                            registered_image_path= output_registered, threads= threads, params= elastix_params, work_dir= tmp_path, verbose= 0)
# Out:
#   0%|          | 0/170 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 11
#       8     output_registered= None
#       9 if (not os.path.isfile(output_skull) or not os.path.isfile(output_head) or
#      10     (save_registered_images and not os.path.isfile(output_registered))):
# ---> 11     maweight.register_and_transform(i, d, [m, h], [output_skull, output_head], moving_mask= b, fixed_mask= db,
#      12                                     registered_image_path= output_registered, threads= threads, params= elastix_params, work_dir= tmp_path, verbose= 0)
#
# File ~/anaconda3/envs/ctweight310/lib/python3.10/site-packages/maweight/_maweight.py:452, in register_and_transform(moving, fixed, to_fit, output_names, params, work_dir, threads, elastix_path, transformix_path, registered_image_path, verbose, moving_mask, fixed_mask)
#     441 if verbose > 2: print('Executing the fitting of %s' % file_arguments[2:][i])
#     442 command= [transformix_path,
#     443           '-in',
#     444           file_arguments[2:][i],
#    (...)
#     449           '-threads',
#     450           str(threads)]
# --> 452 _execute_command(command, verbose)
#     454 if output_names is None:
#     455     if image_dim == 3:
#
# File ~/anaconda3/envs/ctweight310/lib/python3.10/site-packages/maweight/_maweight.py:292, in _execute_command(command, verbose)
#     290         sys.stdout.flush()
#     291 else:
# --> 292     p.communicate()
#
# File ~/anaconda3/envs/ctweight310/lib/python3.10/subprocess.py:1154, in Popen.communicate(self, input, timeout)
#    1151     endtime = None
#    1153 try:
# -> 1154     stdout, stderr = self._communicate(input, endtime, timeout)
#    1155 except KeyboardInterrupt:
#    1156     # https://bugs.python.org/issue25942
#    1157     # See the detailed comment in .wait().
#    1158     if timeout is not None:
#
# File ~/anaconda3/envs/ctweight310/lib/python3.10/subprocess.py:2021, in Popen._communicate(self, input, endtime, orig_timeout)
#    2014     self._check_timeout(endtime, orig_timeout,
#    2015                         stdout, stderr,
#    2016                         skip_check_and_raise=True)
#    2017     raise RuntimeError(  # Impossible :)
#    2018         '_check_timeout(..., skip_check_and_raise=True) '
#    2019         'failed to raise TimeoutExpired.')
# -> 2021 ready = selector.select(timeout)
#    2022 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2024 # XXX Rewrite these to use non-blocking I/O on the file
#    2025 # objects; they are no longer using C stdio!
#
# File ~/anaconda3/envs/ctweight310/lib/python3.10/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:

# %% [markdown]
# ## Segmentation by Registration after registration with bone

# %%
if registration_after_bone_registration:
    for d in tqdm.tqdm(dissected_images):
        for (i, h, m) in zip(manually_segmented_images, manually_segmented_head, manually_segmented_skulls):
            output_skull= os.path.join(output_path, d.split(os.sep)[-1] + '_' + m.split(os.sep)[-1] + '_' + image_format)
            output_head= os.path.join(output_path, d.split(os.sep)[-1] + '_' + h.split(os.sep)[-1] + '_' + image_format)
            if save_registered_images:
                output_registered= os.path.join(output_path, d.split(os.sep)[-1] + '_' + i.split(os.sep)[-1] + '_' + image_format)
            else:
                output_registered= None
            if (not os.path.isfile(output_skull) or not os.path.isfile(output_head) or 
                (save_registered_images and not os.path.isfile(output_registered))):
                maweight.register_and_transform(i, d, [m, h], [output_skull, output_head], 
                                                registered_image_path= output_registered, threads= threads, params= elastix_params, work_dir= tmp_path, verbose= 0)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 179/179 [15:51:24<00:00, 318.91s/it]
